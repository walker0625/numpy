# %%
from PIL import Image
from IPython.display import display
import numpy as np

img = Image.open("resources/capibara.jpg")
display(img)

print('----------------------------------------------')

np_array_img = np.array(img)

print(np_array_img)

print('----------------------------------------------')

print(np_array_img.shape)

print('----------------------------------------------')

display(Image.fromarray(255 - np_array_img))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400>
# ----------------------------------------------
# [[[152 191 248]
#   [151 190 247]
#   [149 188 247]
#   ...
#   [130 181 246]
#   [129 180 245]
#   [129 180 245]]
#
#  [[154 191 246]
#   [155 192 247]
#   [155 192 247]
#   ...
#   [130 181 246]
#   [130 181 246]
#   [130 181 246]]
#
#  [[157 190 241]
#   [157 190 241]
#   [157 190 241]
#   ...
#   [130 181 246]
#   [130 181 246]
#   [130 181 246]]
#
#  ...
#
#  [[199 183 170]
#   [202 186 173]
#   [203 187 174]
#   ...
#   [206 182 154]
#   [209 185 157]
#   [232 208 180]]
#
#  [[188 170 156]
#   [197 179 165]
#   [204 186 172]
#   ...
#   [223 199 171]
#   [185 161 133]
#   [193 169 141]]
#
#  [[179 162 146]
#   [190 173 157]
#   [202 184 170]
#   ...
#   [237 213 185]
#   [195 171 143]
#   [198 174 146]]]
# ----------------------------------------------
# (400, 400, 3)
# ----------------------------------------------
# <PIL.Image.Image image mode=RGB size=400x400>
